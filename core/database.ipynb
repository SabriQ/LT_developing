# %%
from Cdatabase import *
from addinfo2celltype import *

# %%
db = DataBase()

# %%
celltype = db.index_celltypes(mouse_id="201033",part="234",day="20200804")[0]

# %%
ct = CellType(celltype)

# %%
session=ct.find_session()

# %%
size = os.path.getsize(celltype)
size
# Out:
# 5

# %%
save_pkl(result,celltype)
# Out:
# result is saved at \\10.10.47.163\Data_archive\qiushou\results\celltypes\celltype_201033_part234_day20200804_aim_A1B1.pkl

# %%
ct = r"\\10.10.47.163\Data_archive\qiushou\results\celltypes\celltype_201034_part234_day20200805_aim_ce.pkl"

# %%
import pickle

# %%
with open(ct,"rb") as f:
    r = pickle.load(f)

# %%
r = load_pkl(ct)

# %%
r["pccells"]
# Out:
# {'context_0': {'observed_SIs': 0      0.016249
#   2      0.063637
#   3      0.015401
#   4      0.013754
#   5      0.031836
#            ...
#   312    0.005007
#   314    0.011235
#   324    0.031336
#   326    0.075421
#   329    0.077906
#   Length: 120, dtype: float64,
#   'shuffle_SIs':           0         2         3         4         5         6         9    \
#   0    0.024890  0.081280  0.026487  0.020130  0.033305  0.019954  0.028958
#   1    0.023974  0.064127  0.030499  0.022989  0.026261  0.023756  0.013529
#   2    0.030366  0.065013  0.032471  0.021767  0.035393  0.028246  0.025814
#   3    0.012932  0.043714  0.021510  0.013180  0.022468  0.020479  0.027738
#   4    0.019008  0.060589  0.019054  0.013201  0.029559  0.024003  0.019297
#   ..        ...       ...       ...       ...       ...       ...       ...
#   995  0.012564  0.060905  0.014141  0.011820  0.031987  0.020199  0.039182
#   996  0.010375  0.054413  0.009418  0.011660  0.025151  0.043386  0.025616
# ...

# %%
r = pd.read_pickle(ct)

# %%
! pip list
# Out:
# Package                           Version
# --------------------------------- -------------------
# -pencv-python                     4.1.1.26
# absl-py                           0.11.0
# alabaster                         0.7.12
# argh                              0.26.2
# argon2-cffi                       20.1.0
# asn1crypto                        1.3.0
# astor                             0.8.1
# astroid                           2.4.2
# async-generator                   1.10
# atomicwrites                      1.4.0
# attrs                             20.3.0
# autopep8                          1.5.2
# Babel                             2.9.0
# backcall                          0.2.0
# backports.functools-lru-cache     1.6.1
# bcrypt                            3.2.0
# bleach                            3.2.1
# bokeh                             2.0.1
# brotlipy                          0.7.0
# caiman                            1.8.3
# certifi                           2020.12.5
# ...
